# %% [markdown]
# # Importing the required libraries and packages

# %%
import time

import matplotlib.pyplot as plt
import numpy as np

from keras import backend as K
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D, Conv2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
from keras.regularizers import l2
from keras.preprocessing.image import ImageDataGenerator

from keras.datasets import cifar10

% matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
np.random.seed(2017)

# %% [markdown]
# # Loading the data

# %%
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
print(num_test)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 10000

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

fig = plt.figure(figsize=(8,3))

for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)

plt.show()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %% [markdown]
# # Model Architecture
#
# Here, I've changed the model from having Dense layers to the actual Convolution layers.

# %%
# Define the model
model = Sequential()

model.add(Conv2D(32, (3, 3), input_shape=(32, 32, 3))) # 30 - 3rf
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.05))

model.add(Conv2D(64, (3, 3))) # 28 - 5rf
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.05))

model.add(Conv2D(128, (3, 3))) # 26 - 7rf
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.05))

model.add(Conv2D(32, (1, 1))) # 26 - 7rf
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.05))

model.add(MaxPooling2D(pool_size=(2, 2))) # 13 - 8rf
model.add(Dropout(0.05))

model.add(Conv2D(64, (3, 3))) # 11 - 12rf
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.05))

model.add(Conv2D(96, (3, 3))) # 9 - 14rf
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.05))

model.add(Conv2D(128, (3, 3))) # 7 - 16rf
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.05))

model.add(Conv2D(32, (1, 1))) # 7 - 16 rf
model.add(BatchNormalization())
model.add(Dropout(0.05))
model.add(Activation('relu'))

model.add(Conv2D(32, (7, 7))) # 1 - 28rf
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.05))

model.add(Conv2D(10, (1, 1))) # 1 - 28rf

model.add(Flatten())
model.add(Activation('softmax'))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        896
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# activation_1 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 28, 28, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 28, 28, 64)        256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 26, 26, 128)       73856
# _________________________________________________________________
# activation_3 (Activation)    (None, 26, 26, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 26, 26, 128)       512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 26, 26, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 26, 26, 32)        4128
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 26, 26, 32)        128
# _________________________________________________________________
# activation_4 (Activation)    (None, 26, 26, 32)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 26, 26, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 11, 11, 64)        256
# _________________________________________________________________
# activation_5 (Activation)    (None, 11, 11, 64)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 11, 11, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 9, 9, 96)          55392
# _________________________________________________________________
# activation_6 (Activation)    (None, 9, 9, 96)          0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 9, 9, 96)          384
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 9, 9, 96)          0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 7, 7, 128)         110720
# _________________________________________________________________
# activation_7 (Activation)    (None, 7, 7, 128)         0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 7, 7, 128)         512
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 7, 7, 32)          4128
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 7, 7, 32)          128
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 7, 7, 32)          0
# _________________________________________________________________
# activation_8 (Activation)    (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 1, 1, 32)          50208
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 1, 1, 32)          128
# _________________________________________________________________
# activation_9 (Activation)    (None, 1, 1, 32)          0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 1, 1, 32)          0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 1, 1, 10)          330
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_10 (Activation)   (None, 10)                0
# =================================================================
# Total params: 339,082
# Trainable params: 337,866
# Non-trainable params: 1,216
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 50, 
                                 validation_data = (test_features, test_labels), verbose=1, shuffle=False)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, shuffle=False, steps_per_epoch=390, epochs=50)`
#   # Remove the CWD from sys.path while we load stuff.
# Epoch 1/50
# 390/390 [==============================] - 26s 66ms/step - loss: 1.4640 - acc: 0.4721 - val_loss: 1.6826 - val_acc: 0.4869
# Epoch 2/50
# 390/390 [==============================] - 22s 55ms/step - loss: 0.9959 - acc: 0.6490 - val_loss: 1.0561 - val_acc: 0.6275
# Epoch 3/50
# 390/390 [==============================] - 22s 55ms/step - loss: 0.8095 - acc: 0.7171 - val_loss: 0.9065 - val_acc: 0.6864
# Epoch 4/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.7067 - acc: 0.7528 - val_loss: 0.8285 - val_acc: 0.7158
# Epoch 5/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.6332 - acc: 0.7799 - val_loss: 0.7731 - val_acc: 0.7288
# Epoch 6/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.5736 - acc: 0.8028 - val_loss: 0.8338 - val_acc: 0.7184
# Epoch 7/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.5191 - acc: 0.8195 - val_loss: 0.8071 - val_acc: 0.7319
# Epoch 8/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.4856 - acc: 0.8292 - val_loss: 0.6492 - val_acc: 0.7780
# Epoch 9/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.4431 - acc: 0.8461 - val_loss: 0.7172 - val_acc: 0.7645
# Epoch 10/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.4110 - acc: 0.8578 - val_loss: 0.9029 - val_acc: 0.7189
# Epoch 11/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.3842 - acc: 0.8656 - val_loss: 0.7183 - val_acc: 0.7607
# Epoch 12/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.3645 - acc: 0.8731 - val_loss: 0.6749 - val_acc: 0.7847
# Epoch 13/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.3391 - acc: 0.8815 - val_loss: 0.6955 - val_acc: 0.7871
# Epoch 14/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.3133 - acc: 0.8904 - val_loss: 0.7283 - val_acc: 0.7718
# Epoch 15/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.3003 - acc: 0.8930 - val_loss: 0.6298 - val_acc: 0.8031
# Epoch 16/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.2774 - acc: 0.9017 - val_loss: 0.7504 - val_acc: 0.7785
# Epoch 17/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.2590 - acc: 0.9091 - val_loss: 0.6669 - val_acc: 0.7983
# Epoch 18/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.2525 - acc: 0.9100 - val_loss: 0.6544 - val_acc: 0.7984
# Epoch 19/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.2327 - acc: 0.9181 - val_loss: 0.7921 - val_acc: 0.7774
# Epoch 20/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.2260 - acc: 0.9190 - val_loss: 0.7838 - val_acc: 0.7860
# Epoch 21/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.2141 - acc: 0.9243 - val_loss: 0.6969 - val_acc: 0.8063
# Epoch 22/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.2047 - acc: 0.9283 - val_loss: 0.7830 - val_acc: 0.7774
# Epoch 23/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1996 - acc: 0.9282 - val_loss: 0.7180 - val_acc: 0.7968
# Epoch 24/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1853 - acc: 0.9341 - val_loss: 0.7246 - val_acc: 0.8013
# Epoch 25/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1845 - acc: 0.9340 - val_loss: 0.7344 - val_acc: 0.8007
# Epoch 26/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1793 - acc: 0.9355 - val_loss: 0.8440 - val_acc: 0.7820
# Epoch 27/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1705 - acc: 0.9403 - val_loss: 0.7830 - val_acc: 0.7960
# Epoch 28/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1645 - acc: 0.9409 - val_loss: 0.7636 - val_acc: 0.7973
# Epoch 29/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1589 - acc: 0.9444 - val_loss: 0.7527 - val_acc: 0.8011
# Epoch 30/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1514 - acc: 0.9452 - val_loss: 0.7662 - val_acc: 0.7978
# Epoch 31/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1497 - acc: 0.9461 - val_loss: 0.8408 - val_acc: 0.7914
# Epoch 32/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1450 - acc: 0.9490 - val_loss: 0.8376 - val_acc: 0.7898
# Epoch 33/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1427 - acc: 0.9492 - val_loss: 0.8805 - val_acc: 0.7845
# Epoch 34/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1364 - acc: 0.9526 - val_loss: 0.7788 - val_acc: 0.8002
# Epoch 35/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1373 - acc: 0.9512 - val_loss: 0.7585 - val_acc: 0.8130
# Epoch 36/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1332 - acc: 0.9532 - val_loss: 0.7957 - val_acc: 0.8034
# Epoch 37/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1309 - acc: 0.9538 - val_loss: 0.8067 - val_acc: 0.8036
# Epoch 38/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1260 - acc: 0.9548 - val_loss: 0.7740 - val_acc: 0.8092
# Epoch 39/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1208 - acc: 0.9565 - val_loss: 0.8132 - val_acc: 0.8040
# Epoch 40/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1177 - acc: 0.9585 - val_loss: 0.8537 - val_acc: 0.7942
# Epoch 41/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1120 - acc: 0.9609 - val_loss: 0.8232 - val_acc: 0.8048
# Epoch 42/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1133 - acc: 0.9597 - val_loss: 0.8276 - val_acc: 0.8051
# Epoch 43/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1116 - acc: 0.9605 - val_loss: 0.7874 - val_acc: 0.8097
# Epoch 44/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1127 - acc: 0.9602 - val_loss: 0.8021 - val_acc: 0.8047
# Epoch 45/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1089 - acc: 0.9615 - val_loss: 0.7993 - val_acc: 0.8097
# Epoch 46/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1068 - acc: 0.9621 - val_loss: 0.7571 - val_acc: 0.8135
# Epoch 47/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1008 - acc: 0.9635 - val_loss: 0.7754 - val_acc: 0.8119
# Epoch 48/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1007 - acc: 0.9646 - val_loss: 0.8930 - val_acc: 0.7996
# Epoch 49/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1076 - acc: 0.9613 - val_loss: 0.9166 - val_acc: 0.7988
# Epoch 50/50
# 390/390 [==============================] - 21s 55ms/step - loss: 0.1016 - acc: 0.9639 - val_loss: 0.8119 - val_acc: 0.8139
# Model took 1074.07 seconds to train
# Accuracy on test data is: 81.39
