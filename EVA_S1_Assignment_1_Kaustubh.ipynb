# %% [markdown]
# <a href="https://colab.research.google.com/github/kaustubhharapanahalli/EVA-S1/blob/master/EVA_S1_Assignment_1_Kaustubh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### The goal of this project is to extract vertical edge, horizontal edge and 45° edges, and blurring and sharpening the images.

# %%
# import the necessary packages
import numpy as np
from urllib.request import urlopen
import cv2
from matplotlib import pyplot as plt

# METHOD #1: OpenCV, NumPy, and urllib
def url_to_image(url):
	# download the image, convert it to a NumPy array, and then read
	# it into OpenCV format
	resp = urlopen(url)
	image = np.asarray(bytearray(resp.read()), dtype="uint8")
	image = cv2.imdecode(image, cv2.IMREAD_COLOR)
    
    # return the image
	return image

# %%
image = url_to_image("https://fontsarena-cd5e.kxcdn.com/wp-content/uploads/2019/04/helvetica-now-font-400x364.png")

# %%
# Plotting the image using cv2_imshow
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F78CB4DB518>

# %% [markdown]
# Canny Edge Detection is a multi-steps edge detection process. The multiple steps are listed below:
# * Noise Reduction
# * Finding Intensity Gradient of the Image
# * Non-maximum suppression
# * Hysteresis Thresholding
#
# The explanation of each of these steps are given in the documentation. The link to the documentation of Canny Edge Detection is [https://docs.opencv.org/3.1.0/da/d22/tutorial_py_canny.html](Canny Edge Detection Link).

# %%
edges = cv2.Canny(image,100,200)

# %%
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=400x364 at 0x7F78CB4DB908>

# %% [markdown]
# In the code below, we are getting the right vertical edges.

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[-1,0,1],[-1,0,1],[-1,0,1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F78CB4D8588>

# %% [markdown]
# In the code below, we are getting the top horizontal edges.

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[1,1,1],[0,0,0],[-1,-1,-1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F78CB4DD630>

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[-1,-1,-1],[0,0,0],[1,1,1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F78CB4DB6A0>

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[-1,1,-1],[0,0,0],[1,-1,1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F78CB4DB710>

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[0,-1,0],[0,1,0],[0,0,0]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F78CB4DB6A0>

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[0,1,0],[0,0,0],[0,-1,0]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F78CB4DB588>

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[0,-1,0],[-1,5,-1],[0,-1,0]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F78CB4DB780>

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[-1,-1,-1],[1,1,1],[-1,-1,-1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F78CB4DB9E8>
